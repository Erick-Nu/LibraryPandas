# %%
import pandas as pd

# %%
data = {
    'manzanas' : [3,2,0,1],
    'naranjas' : [0,3,7,20]
}

# %%
compras = pd.DataFrame(data)
compras
# Out:
#    manzanas  naranjas
# 0         3         0
# 1         2         3
# 2         0         7
# 3         1        20

# %%
dataF = pd.DataFrame(data, index = ["Erick","Jhonny","Juan","Adrian"])

# %%
dataF
# Out:
#         manzanas  naranjas
# Erick          3         0
# Jhonny         2         3
# Juan           0         7
# Adrian         1        20

# %%
# Consultas
comprasOne = pd.DataFrame(data, index = ['Erick','Nuñez','Adrian','Damaris'])

# %%
comprasOne
# Out:
#          manzanas  naranjas
# Erick           3         0
# Nuñez           2         3
# Adrian          0         7
# Damaris         1        20

# %%
# Consultas
comprasOne.loc['Erick']
# Out:
# manzanas    3
# naranjas    0
# Name: Erick, dtype: int64

# %%
# Transformar una tabla en un archivo csv
df = comprasOne.to_csv('comprasOne.csv')

# %%
# Transformar una tabla en un archivo json
df2 = comprasOne.to_json('comprasTwo.json')

# %%
# Abrir archivos csv
df = pd.read_csv('comprasOne.csv',index_col=0)
df
# Out:
#          manzanas  naranjas
# Erick           3         0
# Nuñez           2         3
# Adrian          0         7
# Damaris         1        20

# %%
# Abrir archivos json
df2 = pd.read_json('comprasTwo.json')
df2
# Out:
#          manzanas  naranjas
# Erick          25        12
# Nuñez           2         3
# Adrian         30        40
# Damaris         1        23

# %%
# Leer exel con panda   s

# %%
# instalacion de sql Lite
import sqlite3 as sq

# %%
con = sq.connect("comprasFour.db")

# %%
df = pd.read_sql_query('select * from frutas',con)
df
# Out:
#     index  naranjas  manzanas  peras
# 0   Erick        45        12     10
# 1  Adrian        10        15     13
# 2  Jhonny        15         8     17

# %%
df = pd.read_sql_query('select * from frutas',con)
df
# Out:
#     index  naranjas  manzanas  peras
# 0   Erick        45        12     10
# 1  Adrian        10        15     13
# 2  Jhonny        15         8     17

# %%
# Agregar un index
df = df.set_index('index')
df
# Out:
#         naranjas  manzanas  peras
# index
# Erick         45        12     10
# Adrian        10        15     13
# Jhonny        15         8     17

# %%
# Agregar una tabla
compras.to_sql('nuevas_compras',con)
# Out:
# 4

# %%
# Abrimos un dataset de peliculas
movies_df = pd.read_csv("IMDB-Movie-Data.csv", index_col="Title")
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
# Mostrar un numero determinado de registros
movies_df.head(20)
# Out:
#                                          Rank                       Genre  \
# Title
# Guardians of the Galaxy                     1     Action,Adventure,Sci-Fi
# Prometheus                                  2    Adventure,Mystery,Sci-Fi
# Split                                       3             Horror,Thriller
# Sing                                        4     Animation,Comedy,Family
# Suicide Squad                               5    Action,Adventure,Fantasy
# The Great Wall                              6    Action,Adventure,Fantasy
# La La Land                                  7          Comedy,Drama,Music
# Mindhorn                                    8                      Comedy
# The Lost City of Z                          9  Action,Adventure,Biography
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# ...

# %%
#  Informacion de la base de datos
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
# Tamaño de las filas y columnas
movies_df.shape
# Out:
# (1000, 11)

# %%
# Duplicacion de elementos, en este caso concatenamos el mismo archivo por eso se genra la duplicacion
temp_df = pd.concat([movies_df,movies_df])
temp_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
# Eliminar duplicados
temp_df = temp_df.drop_duplicates()
temp_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.isnull()
# Out:
#                           Rank  Genre  Description  Director  Actors   Year  \
# Title
# Guardians of the Galaxy  False  False        False     False   False  False
# Prometheus               False  False        False     False   False  False
# Split                    False  False        False     False   False  False
# Sing                     False  False        False     False   False  False
# Suicide Squad            False  False        False     False   False  False
# ...                        ...    ...          ...       ...     ...    ...
# Secret in Their Eyes     False  False        False     False   False  False
# Hostel: Part II          False  False        False     False   False  False
# Step Up 2: The Streets   False  False        False     False   False  False
# Search Party             False  False        False     False   False  False
# Nine Lives               False  False        False     False   False  False
#
# ...

# %%
# Sumas nulos
movies_df.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
# Eliminar nulos
movies2 = movies_df.dropna()

# %%
movies2.isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
revenue = movies_df['Revenue (Millions)']
revenue
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
#                             ...
# Secret in Their Eyes          NaN
# Hostel: Part II             17.54
# Step Up 2: The Streets      58.01
# Search Party                  NaN
# Nine Lives                  19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
# Obtener el promdio
revenue_mean  = revenue.mean()

# %%
revenue_mean
# Out:
# np.float64(82.95637614678898)

# %%
# Remplazo de los nulos
revenue.fillna(revenue_mean, inplace = True)

# %%
movies_df.isnull().sum()
# Out:
# Rank                   0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %%
movies_df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count         1000.000000  936.000000
# mean            82.956376   58.985043
# std             96.412043   17.194757
# min              0.000000   11.000000
# 25%             17.442500   47.000000
# ...

# %%
# Describir una columna
movies_df["Genre"].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: Genre, dtype: object

# %%
movies_df["Genre"].value_counts().head(10)
# Out:
# Genre
# Action,Adventure,Sci-Fi       50
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Animation,Adventure,Comedy    27
# Action,Adventure,Fantasy      27
# Comedy,Drama                  27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Name: count, dtype: int64
